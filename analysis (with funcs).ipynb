# %%
import encapsulation as enc

# %%
df = enc.df_import_clean('attacks.csv')

# %%
df = enc.further_clean(df)

# %%
enc.vis1(df)

# %%
enc.vis2(df)

# %%
enc.vis3(enc.top_countries(df)[0], enc.top_countries(df)[1])

# %%
enc.vis4(enc.top_countries(df)[1], df)

# %%
enc.vis5(df)

# %%
enc.vis6(df)

# %%
enc.vis7(df, enc.top_countries(df)[1])

# %%
enc.vis8(df)

# %%
enc.vis9(df)

# %%
enc.vis10(df)

# %%
enc.vis11(df)
